# %% [markdown]
# <a href="https://colab.research.google.com/github/changliu17/dsfigures/blob/master/gradient.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Library needed

import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from skimage.color import rgb2gray
from skimage.io import imread
from skimage import filters

# %%
# im = rgb2gray(imread('chicken.jpg'))
img = cv.imread('chicken.jpg',0)

# %%
# plt.gray()
plt.figure(figsize=(20,20))
plt.subplot(131)
plt.imshow(im)
plt.title('original', size=20)


plt.subplot(132)
sobelx = cv.Sobel(im,cv.CV_64F,1,0,ksize=9)
plt.imshow(sobelx,cmap = 'gray')
plt.title('sobel_x', size=20)

plt.subplot(133)
sobely = cv.Sobel(im, cv.CV_64F, 0, 1, ksize = 9)
plt.imshow(sobely, cmap = 'gray')
plt.title('sobel_y', size=20)
# plt.show()
# Out:
# Text(0.5, 1.0, 'sobel_y')

# %%
# plt.gray()
plt.figure(figsize=(20,20))
plt.subplot(131)
plt.imshow(im)
plt.title('original', size=20)


plt.subplot(132)
sobelx = cv.Sobel(im,cv.CV_64F,1,0,ksize=7)
plt.imshow(sobelx,cmap = 'gray')
plt.title('sobel_x', size=20)

plt.subplot(133)
sobely = cv.Sobel(im, cv.CV_64F, 0, 1, ksize = 7)
plt.imshow(sobely, cmap = 'gray')
plt.title('sobel_y', size=20)
# plt.show()
# Out:
# Text(0.5, 1.0, 'sobel_y')

# %%
img = rgb2gray(imread('chicken.png'))

# %%
# plt.gray()
plt.figure(figsize=(20,20))
plt.subplot(131)
plt.imshow(img)
plt.title('original', size=20)


plt.subplot(132)
sobelx = cv.Sobel(img,cv.CV_64F,1,0,ksize=5)
plt.imshow(sobelx,cmap = 'gray')
plt.title('sobel_x', size=20)

plt.subplot(133)
sobely = cv.Sobel(img, cv.CV_64F, 0, 1, ksize = 5)
plt.imshow(sobely, cmap = 'gray')
plt.title('sobel_y', size=20)
# plt.show()
# Out:
# Text(0.5, 1.0, 'sobel_y')
